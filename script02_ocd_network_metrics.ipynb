# %%
## using traditional network analysis as a comparision for our method.
import os
import glob
import pandas as pd
import numpy as np
import re
import networkx as nx
import networkx.algorithms.community as nx_comm
import matplotlib.pyplot as plt

input_dir = 'ocd_out01_correlation_matrix_hc'
input_dir2 = 'ocd_out01_correlation_matrix_ocd'

output_dir = 'ocd_out03_network_analysis'

input_files = glob.glob(input_dir + '/CorrelationMatrix_*.csv')
input_files.sort()

input_files2 = glob.glob(input_dir2 + '/CorrelationMatrix_*.csv')
input_files2.sort()

input_files
# Out:
# ['ocd_out01_correlation_matrix_hc/CorrelationMatrix_sub051.csv',
#  'ocd_out01_correlation_matrix_hc/CorrelationMatrix_sub052.csv',
#  'ocd_out01_correlation_matrix_hc/CorrelationMatrix_sub053.csv',
#  'ocd_out01_correlation_matrix_hc/CorrelationMatrix_sub054.csv',
#  'ocd_out01_correlation_matrix_hc/CorrelationMatrix_sub055.csv',
#  'ocd_out01_correlation_matrix_hc/CorrelationMatrix_sub056.csv',
#  'ocd_out01_correlation_matrix_hc/CorrelationMatrix_sub057.csv',
#  'ocd_out01_correlation_matrix_hc/CorrelationMatrix_sub058.csv',
#  'ocd_out01_correlation_matrix_hc/CorrelationMatrix_sub059.csv',
#  'ocd_out01_correlation_matrix_hc/CorrelationMatrix_sub060.csv',
#  'ocd_out01_correlation_matrix_hc/CorrelationMatrix_sub061.csv',
#  'ocd_out01_correlation_matrix_hc/CorrelationMatrix_sub062.csv',
#  'ocd_out01_correlation_matrix_hc/CorrelationMatrix_sub063.csv',
#  'ocd_out01_correlation_matrix_hc/CorrelationMatrix_sub064.csv',
#  'ocd_out01_correlation_matrix_hc/CorrelationMatrix_sub065.csv',
#  'ocd_out01_correlation_matrix_hc/CorrelationMatrix_sub066.csv',
#  'ocd_out01_correlation_matrix_hc/CorrelationMatrix_sub067.csv',
#  'ocd_out01_correlation_matrix_hc/CorrelationMatrix_sub068.csv',
#  'ocd_out01_correlation_matrix_hc/CorrelationMatrix_sub069.csv',
#  'ocd_out01_correlation_matrix_hc/CorrelationMatrix_sub070.csv',
#  'ocd_out01_correlation_matrix_hc/CorrelationMatrix_sub071.csv',
#  'ocd_out01_correlation_matrix_hc/CorrelationMatrix_sub072.csv',
#  'ocd_out01_correlation_matrix_hc/CorrelationMatrix_sub073.csv',
#  'ocd_out01_correlation_matrix_hc/CorrelationMatrix_sub074.csv',
#  'ocd_out01_correlation_matrix_hc/CorrelationMatrix_sub075.csv',
#  'ocd_out01_correlation_matrix_hc/CorrelationMatrix_subc_001.csv',
#  'ocd_out01_correlation_matrix_hc/CorrelationMatrix_subc_002.csv',
#  'ocd_out01_correlation_matrix_hc/CorrelationMatrix_subc_003.csv',
#  'ocd_out01_correlation_matrix_hc/CorrelationMatrix_subc_004.csv',
#  'ocd_out01_correlation_matrix_hc/CorrelationMatrix_subc_005.csv',
#  'ocd_out01_correlation_matrix_hc/CorrelationMatrix_subc_006.csv',
#  'ocd_out01_correlation_matrix_hc/CorrelationMatrix_subc_007.csv',
#  'ocd_out01_correlation_matrix_hc/CorrelationMatrix_subc_008.csv',
#  'ocd_out01_correlation_matrix_hc/CorrelationMatrix_subc_009.csv',
#  'ocd_out01_correlation_matrix_hc/CorrelationMatrix_subc_011.csv',
#  'ocd_out01_correlation_matrix_hc/CorrelationMatrix_subc_012.csv',
#  'ocd_out01_correlation_matrix_hc/CorrelationMatrix_subc_013.csv',
#  'ocd_out01_correlation_matrix_hc/CorrelationMatrix_subc_014.csv',
#  'ocd_out01_correlation_matrix_hc/CorrelationMatrix_subc_016.csv',
#  'ocd_out01_correlation_matrix_hc/CorrelationMatrix_subc_017.csv',
#  'ocd_out01_correlation_matrix_hc/CorrelationMatrix_subc_018.csv',
#  'ocd_out01_correlation_matrix_hc/CorrelationMatrix_subc_019.csv',
#  'ocd_out01_correlation_matrix_hc/CorrelationMatrix_subc_020.csv',
#  'ocd_out01_correlation_matrix_hc/CorrelationMatrix_subc_021.csv',
#  'ocd_out01_correlation_matrix_hc/CorrelationMatrix_subc_022.csv']

# %%
num_hc = len(input_files)
num_ocd = len(input_files2)

subject_info = pd.DataFrame({'group': ['hc'] * num_hc + ['ocd'] * num_ocd})

input_files += input_files2

# %%
all_clustering = []
all_betweenness = []
all_modularity = []
all_degree = []
all_eigenvector = []
all_closeness = []

for f in input_files:
    print(f)
    df_corr = pd.read_csv(f, header = None)
    
    # use int index and columns name so that the order is correctly sorted.
    df_corr.index = [i for i in range(1, len(df_corr) + 1)]
    df_corr.columns = [i for i in range(1, len(df_corr) + 1)]
    
    links = df_corr.stack().reset_index()
    links.columns = ['roi1', 'roi2', 'corr']
    
    # use same threshold in the harmonic analysis:
    links_filtered=links.loc[(links['corr'] > 0.07) & (links['roi1'] != links['roi2'])]
 
    # Build your graph
    G=nx.from_pandas_edgelist(links_filtered, 'roi1', 'roi2')

    ## clustering coefficient:
    clustering = nx.clustering(G)
    clustering_list = [clustering[key] for key in sorted(clustering.keys())]
    all_clustering.append(clustering_list)
    
    ## betweenness:
    betweeness = nx.betweenness_centrality(G)
    betweeness_list = [betweeness[key] for key in sorted(betweeness.keys())]
    all_betweenness.append(betweeness_list)
    
    ## degree centrality:
    degree = nx.degree_centrality(G)
    degree_list = [degree[key] for key in sorted(degree.keys())]
    all_degree.append(degree_list)

    ## modularity:
    modularity = nx_comm.modularity(G, nx_comm.label_propagation_communities(G))
    all_modularity.append(modularity)
    
    ## eigenvector:
    eigenvector = nx.eigenvector_centrality(G)
    eigenvector_list = [eigenvector[key] for key in sorted(eigenvector.keys())]
    all_eigenvector.append(eigenvector_list)
    
    ## closeness:
    closeness = nx.closeness_centrality(G)
    closeness_list = [closeness[key] for key in sorted(closeness.keys())]
    all_closeness.append(closeness_list)
    
    # break
print('finished!')
# Out:
# ocd_out01_correlation_matrix_hc/CorrelationMatrix_sub051.csv
# ocd_out01_correlation_matrix_hc/CorrelationMatrix_sub052.csv
# ocd_out01_correlation_matrix_hc/CorrelationMatrix_sub053.csv
# ocd_out01_correlation_matrix_hc/CorrelationMatrix_sub054.csv
# ocd_out01_correlation_matrix_hc/CorrelationMatrix_sub055.csv
# ocd_out01_correlation_matrix_hc/CorrelationMatrix_sub056.csv
# ocd_out01_correlation_matrix_hc/CorrelationMatrix_sub057.csv
# ocd_out01_correlation_matrix_hc/CorrelationMatrix_sub058.csv
# ocd_out01_correlation_matrix_hc/CorrelationMatrix_sub059.csv
# ocd_out01_correlation_matrix_hc/CorrelationMatrix_sub060.csv
# ocd_out01_correlation_matrix_hc/CorrelationMatrix_sub061.csv
# ocd_out01_correlation_matrix_hc/CorrelationMatrix_sub062.csv
# ocd_out01_correlation_matrix_hc/CorrelationMatrix_sub063.csv
# ocd_out01_correlation_matrix_hc/CorrelationMatrix_sub064.csv
# ocd_out01_correlation_matrix_hc/CorrelationMatrix_sub065.csv
# ocd_out01_correlation_matrix_hc/CorrelationMatrix_sub066.csv
# ocd_out01_correlation_matrix_hc/CorrelationMatrix_sub067.csv
# ocd_out01_correlation_matrix_hc/CorrelationMatrix_sub068.csv
# ocd_out01_correlation_matrix_hc/CorrelationMatrix_sub069.csv
# ocd_out01_correlation_matrix_hc/CorrelationMatrix_sub070.csv
# ocd_out01_correlation_matrix_hc/CorrelationMatrix_sub071.csv
# ocd_out01_correlation_matrix_hc/CorrelationMatrix_sub072.csv
# ocd_out01_correlation_matrix_hc/CorrelationMatrix_sub073.csv
# ocd_out01_correlation_matrix_hc/CorrelationMatrix_sub074.csv
# ocd_out01_correlation_matrix_hc/CorrelationMatrix_sub075.csv
# ocd_out01_correlation_matrix_hc/CorrelationMatrix_subc_001.csv
# ocd_out01_correlation_matrix_hc/CorrelationMatrix_subc_002.csv
# ocd_out01_correlation_matrix_hc/CorrelationMatrix_subc_003.csv
# ocd_out01_correlation_matrix_hc/CorrelationMatrix_subc_004.csv
# ocd_out01_correlation_matrix_hc/CorrelationMatrix_subc_005.csv
# ocd_out01_correlation_matrix_hc/CorrelationMatrix_subc_006.csv
# ocd_out01_correlation_matrix_hc/CorrelationMatrix_subc_007.csv
# ocd_out01_correlation_matrix_hc/CorrelationMatrix_subc_008.csv
# ocd_out01_correlation_matrix_hc/CorrelationMatrix_subc_009.csv
# ocd_out01_correlation_matrix_hc/CorrelationMatrix_subc_011.csv
# ocd_out01_correlation_matrix_hc/CorrelationMatrix_subc_012.csv
# ocd_out01_correlation_matrix_hc/CorrelationMatrix_subc_013.csv
# ocd_out01_correlation_matrix_hc/CorrelationMatrix_subc_014.csv
# ocd_out01_correlation_matrix_hc/CorrelationMatrix_subc_016.csv
# ocd_out01_correlation_matrix_hc/CorrelationMatrix_subc_017.csv
# ocd_out01_correlation_matrix_hc/CorrelationMatrix_subc_018.csv
# ocd_out01_correlation_matrix_hc/CorrelationMatrix_subc_019.csv
# ocd_out01_correlation_matrix_hc/CorrelationMatrix_subc_020.csv
# ocd_out01_correlation_matrix_hc/CorrelationMatrix_subc_021.csv
# ocd_out01_correlation_matrix_hc/CorrelationMatrix_subc_022.csv
# ocd_out01_correlation_matrix_ocd/CorrelationMatrix_sub_001.csv
# ocd_out01_correlation_matrix_ocd/CorrelationMatrix_sub_003.csv
# ocd_out01_correlation_matrix_ocd/CorrelationMatrix_sub_004.csv
# ocd_out01_correlation_matrix_ocd/CorrelationMatrix_sub_007.csv
# ocd_out01_correlation_matrix_ocd/CorrelationMatrix_sub_012.csv
# ocd_out01_correlation_matrix_ocd/CorrelationMatrix_sub_013.csv
# ocd_out01_correlation_matrix_ocd/CorrelationMatrix_sub_016.csv
# ocd_out01_correlation_matrix_ocd/CorrelationMatrix_sub_018.csv
# ocd_out01_correlation_matrix_ocd/CorrelationMatrix_sub_019.csv
# ocd_out01_correlation_matrix_ocd/CorrelationMatrix_sub_020.csv
# ocd_out01_correlation_matrix_ocd/CorrelationMatrix_sub_022.csv
# ocd_out01_correlation_matrix_ocd/CorrelationMatrix_sub_023.csv
# ocd_out01_correlation_matrix_ocd/CorrelationMatrix_sub_024.csv
# ocd_out01_correlation_matrix_ocd/CorrelationMatrix_sub_027.csv
# ocd_out01_correlation_matrix_ocd/CorrelationMatrix_sub_029.csv
# ocd_out01_correlation_matrix_ocd/CorrelationMatrix_sub_031.csv
# ocd_out01_correlation_matrix_ocd/CorrelationMatrix_sub_032.csv
# ocd_out01_correlation_matrix_ocd/CorrelationMatrix_sub_035.csv
# ocd_out01_correlation_matrix_ocd/CorrelationMatrix_sub_039.csv
# ocd_out01_correlation_matrix_ocd/CorrelationMatrix_sub_040.csv
# ocd_out01_correlation_matrix_ocd/CorrelationMatrix_sub_041.csv
# ocd_out01_correlation_matrix_ocd/CorrelationMatrix_sub_042.csv
# ocd_out01_correlation_matrix_ocd/CorrelationMatrix_sub_043.csv
# ocd_out01_correlation_matrix_ocd/CorrelationMatrix_sub_044.csv
# ocd_out01_correlation_matrix_ocd/CorrelationMatrix_sub_046.csv
# ocd_out01_correlation_matrix_ocd/CorrelationMatrix_sub_047.csv
# ocd_out01_correlation_matrix_ocd/CorrelationMatrix_sub_048.csv
# ocd_out01_correlation_matrix_ocd/CorrelationMatrix_sub_049.csv
# ocd_out01_correlation_matrix_ocd/CorrelationMatrix_sub_050.csv
# ocd_out01_correlation_matrix_ocd/CorrelationMatrix_sub_051.csv
# ocd_out01_correlation_matrix_ocd/CorrelationMatrix_sub_053.csv
# ocd_out01_correlation_matrix_ocd/CorrelationMatrix_sub_054.csv
# ocd_out01_correlation_matrix_ocd/CorrelationMatrix_sub_055.csv
# ocd_out01_correlation_matrix_ocd/CorrelationMatrix_sub_056.csv
# ocd_out01_correlation_matrix_ocd/CorrelationMatrix_sub_060.csv
# finished!

# %%
df_corr
# Out:
#           1         2         3         4         5         6         7    \
# 1    1.000000  0.613196 -0.019632 -0.260923 -0.151200 -0.255233 -0.199297
# 2    0.613196  1.000000 -0.366717 -0.198479 -0.299856 -0.000340  0.010893
# 3   -0.019632 -0.366717  1.000000  0.423185  0.433879  0.008941  0.458385
# 4   -0.260923 -0.198479  0.423185  1.000000  0.280348  0.503760  0.250963
# 5   -0.151200 -0.299856  0.433879  0.280348  1.000000  0.454918  0.280880
# ..        ...       ...       ...       ...       ...       ...       ...
# 112 -0.091368 -0.136906  0.124196 -0.113298 -0.011255 -0.006000 -0.046437
# 113 -0.216627 -0.169667  0.026299  0.054686  0.224694  0.233103  0.050308
# 114  0.079369  0.096908 -0.126748 -0.227713  0.031393  0.136816 -0.163700
# 115  0.025441 -0.078694 -0.053261 -0.015083  0.149511  0.223497 -0.187926
# 116 -0.016953 -0.199680 -0.086360 -0.218957  0.099932  0.107804 -0.028721
#
#           8         9         10   ...       107       108       109  \
# 1   -0.292537 -0.101164 -0.239605  ... -0.200571 -0.146157  0.307772
# 2    0.114132 -0.227422 -0.045697  ... -0.147400 -0.087979  0.191521
# 3    0.082147  0.498784  0.159279  ... -0.061359  0.090279 -0.139217
# 4    0.511380  0.246318  0.438867  ...  0.062556  0.076080 -0.223229
# 5    0.244081  0.542919  0.367619  ...  0.088588  0.156443  0.054916
# ..        ...       ...       ...  ...       ...       ...       ...
# 112 -0.129017  0.040097  0.060090  ...  0.413490  0.185701  0.088658
# 113  0.014992  0.114658  0.131346  ...  0.459028  0.393791  0.094887
# 114 -0.173692  0.147824  0.048601  ... -0.065089 -0.245435  0.197844
# 115 -0.097214  0.157314  0.127852  ...  0.035750  0.031643  0.132166
# 116 -0.114956  0.008492  0.069937  ...  0.128505  0.338906  0.125034
#
#           110       111       112       113       114       115       116
# 1    0.452441  0.084717 -0.091368 -0.216627  0.079369  0.025441 -0.016953
# 2    0.313187 -0.077263 -0.136906 -0.169667  0.096908 -0.078694 -0.199680
# 3   -0.178721 -0.094352  0.124196  0.026299 -0.126748 -0.053261 -0.086360
# 4   -0.183066  0.013616 -0.113298  0.054686 -0.227713 -0.015083 -0.218957
# 5   -0.131170 -0.030668 -0.011255  0.224694  0.031393  0.149511  0.099932
# ..        ...       ...       ...       ...       ...       ...       ...
# 112  0.054557  0.361053  1.000000  0.497173  0.120745  0.191446  0.194664
# 113  0.117907  0.288293  0.497173  1.000000  0.320755  0.278585  0.332345
# 114  0.256476  0.243961  0.120745  0.320755  1.000000  0.570990  0.152584
# 115  0.136120  0.327791  0.191446  0.278585  0.570990  1.000000  0.489145
# 116  0.048307  0.063167  0.194664  0.332345  0.152584  0.489145  1.000000
#
# [116 rows x 116 columns]

# %%
if not os.path.exists(output_dir):
    os.mkdir(output_dir)
    
for res, fname in [[all_clustering, 'clustering'], [all_modularity, 'modularity'], 
                   [all_betweenness, 'betweenness'], [all_eigenvector, 'eigenvector'],
                   [all_degree, 'degree'], [all_closeness, 'closeness']]:
    df = pd.DataFrame(res)
    output_clustering = pd.concat([subject_info, df], axis = 1)
    output_clustering.to_csv(output_dir + '/' + fname + '.csv')
