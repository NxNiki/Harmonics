# %%
## compute entropy of specturm signals as biomarkers
import glob
import pandas as pd
import numpy as np
import re
import os

## read harmonics and time signals:

## hcp data:
# input_harmonics_wavelets = 'hcp_out02_harmonics_100'
# input_time_signal = '/home/xin/Downloads/FullData_Oct26/Scan1/'
# output_dir = 'hcp_out03_spectrum_power'

## adni data:
input_harmonics_wavelets = 'adni_out02_harmonics'
input_time_signal = '/home/xin/Downloads/BrainImaging_UNC/out04_adni_roi_signals1'
output_dir = 'adni_out03_spectrum_power'

## Notes:
# got NaN values in wavelets (e.g for ROI 3 all values are nan), 
# but time signals does not have nans...
# need to check where those NaNs are derived...

if not os.path.isdir(output_dir):
    os.mkdir(output_dir)
    
harmonic_wavelets_files = glob.glob(input_harmonics_wavelets + '/CommonHarWavelets_Harmonics*.csv')
harmonic_wavelets_files.sort()

time_signal_files = glob.glob(input_time_signal + '/roi_signals_power264*.txt')
# time_signal_files = glob.glob(input_time_signal + '/TimeSeries*.csv')

# %%
# for each wavelets (corresponding to a brain region) calcluate inner product with roi signals for each subject:

spectrum_list = [] # nested array with row: brain region and column: subject.
brain_region_list = []
subject_id_list = []
fill_subject_id = True 
test_break = False

for file_wavelets in harmonic_wavelets_files:
    print(file_wavelets)
    spectrum_sub_list = []
    wavelets = pd.read_csv(file_wavelets, header = None)
    
    if wavelets.isna().any(axis = None):
        print('Nan values for wavelets:' + file_wavelets)
        continue
    
    brain_region = file_wavelets[-7:-4]
    brain_region_list.append(brain_region)
    
    for file_time_signal in time_signal_files:
        
        ## adni:
        subject_id = re.search('roi_signals_power264_(.*).txt', file_time_signal).group(1)
        time_signal = pd.read_csv(file_time_signal, header = 0, sep = '\t')
        time_signal.drop(columns = ['Unnamed: 264'], inplace = True)
        time_signal.columns = time_signal.columns.astype(int)
        time_signal = time_signal.sort_index(ascending=True, axis=1)
        
        ## hcp:
        # subject_id = re.search('TimeSeries(.*).csv', file_time_signal).group(1)
        # time_signal = pd.read_csv(file_time_signal, header = None, sep = ',')
        # time_signal = time_signal.T
        
        # print(subject_id)

        # check nan values:
        if time_signal.isna().any(axis = None):
            print('Nan value for time_signal:' + subject_id)
            # test_break = True
            continue

        # we could use this to directly skip files with NaN values. not implemented yet...
        if fill_subject_id:
            subject_id_list.append(subject_id)
        
        ## compute inner product for each time point:
        P = np.matmul(time_signal.values, wavelets.values)
        spectrum_sub_list.append(P)
    
#     if test_break:
#         break
        
    fill_subject_id = False
    spectrum_list.append(spectrum_sub_list)
# Out:
# adni_out02_harmonics/CommonHarWavelets_Harmonics001.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics002.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics003.csv
# Nan values for wavelets:adni_out02_harmonics/CommonHarWavelets_Harmonics003.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics004.csv
# Nan values for wavelets:adni_out02_harmonics/CommonHarWavelets_Harmonics004.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics005.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics006.csv
# Nan values for wavelets:adni_out02_harmonics/CommonHarWavelets_Harmonics006.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics007.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics008.csv
# Nan values for wavelets:adni_out02_harmonics/CommonHarWavelets_Harmonics008.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics009.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics010.csv
# Nan values for wavelets:adni_out02_harmonics/CommonHarWavelets_Harmonics010.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics011.csv
# Nan values for wavelets:adni_out02_harmonics/CommonHarWavelets_Harmonics011.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics012.csv
# Nan values for wavelets:adni_out02_harmonics/CommonHarWavelets_Harmonics012.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics013.csv
# Nan values for wavelets:adni_out02_harmonics/CommonHarWavelets_Harmonics013.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics014.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics015.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics016.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics017.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics018.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics019.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics020.csv
# Nan values for wavelets:adni_out02_harmonics/CommonHarWavelets_Harmonics020.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics021.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics022.csv
# Nan values for wavelets:adni_out02_harmonics/CommonHarWavelets_Harmonics022.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics023.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics024.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics025.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics026.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics027.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics028.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics029.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics030.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics031.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics032.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics033.csv
# Nan values for wavelets:adni_out02_harmonics/CommonHarWavelets_Harmonics033.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics034.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics035.csv
# Nan values for wavelets:adni_out02_harmonics/CommonHarWavelets_Harmonics035.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics036.csv
# Nan values for wavelets:adni_out02_harmonics/CommonHarWavelets_Harmonics036.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics037.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics038.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics039.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics040.csv
# Nan values for wavelets:adni_out02_harmonics/CommonHarWavelets_Harmonics040.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics041.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics042.csv
# Nan values for wavelets:adni_out02_harmonics/CommonHarWavelets_Harmonics042.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics043.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics044.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics045.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics046.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics047.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics048.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics049.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics050.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics051.csv
# Nan values for wavelets:adni_out02_harmonics/CommonHarWavelets_Harmonics051.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics052.csv
# Nan values for wavelets:adni_out02_harmonics/CommonHarWavelets_Harmonics052.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics053.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics054.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics055.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics056.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics057.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics058.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics059.csv
# Nan values for wavelets:adni_out02_harmonics/CommonHarWavelets_Harmonics059.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics060.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics061.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics062.csv
# Nan values for wavelets:adni_out02_harmonics/CommonHarWavelets_Harmonics062.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics063.csv
# Nan values for wavelets:adni_out02_harmonics/CommonHarWavelets_Harmonics063.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics064.csv
# Nan values for wavelets:adni_out02_harmonics/CommonHarWavelets_Harmonics064.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics065.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics066.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics067.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics068.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics069.csv
# Nan values for wavelets:adni_out02_harmonics/CommonHarWavelets_Harmonics069.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics070.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics071.csv
# Nan values for wavelets:adni_out02_harmonics/CommonHarWavelets_Harmonics071.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics072.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics073.csv
# Nan values for wavelets:adni_out02_harmonics/CommonHarWavelets_Harmonics073.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics074.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics075.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics076.csv
# Nan values for wavelets:adni_out02_harmonics/CommonHarWavelets_Harmonics076.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics077.csv
# Nan values for wavelets:adni_out02_harmonics/CommonHarWavelets_Harmonics077.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics078.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics079.csv
# Nan values for wavelets:adni_out02_harmonics/CommonHarWavelets_Harmonics079.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics080.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics081.csv
# Nan values for wavelets:adni_out02_harmonics/CommonHarWavelets_Harmonics081.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics082.csv
# Nan values for wavelets:adni_out02_harmonics/CommonHarWavelets_Harmonics082.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics083.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics084.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics085.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics086.csv
# Nan values for wavelets:adni_out02_harmonics/CommonHarWavelets_Harmonics086.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics087.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics088.csv
# Nan values for wavelets:adni_out02_harmonics/CommonHarWavelets_Harmonics088.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics089.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics090.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics091.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics092.csv
# Nan values for wavelets:adni_out02_harmonics/CommonHarWavelets_Harmonics092.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics093.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics094.csv
# Nan values for wavelets:adni_out02_harmonics/CommonHarWavelets_Harmonics094.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics095.csv
# Nan values for wavelets:adni_out02_harmonics/CommonHarWavelets_Harmonics095.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics096.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics097.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics098.csv
# Nan values for wavelets:adni_out02_harmonics/CommonHarWavelets_Harmonics098.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics099.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics100.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics101.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics102.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics103.csv
# Nan values for wavelets:adni_out02_harmonics/CommonHarWavelets_Harmonics103.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics104.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics105.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics106.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics107.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics108.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics109.csv
# Nan values for wavelets:adni_out02_harmonics/CommonHarWavelets_Harmonics109.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics110.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics111.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics112.csv
# Nan values for wavelets:adni_out02_harmonics/CommonHarWavelets_Harmonics112.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics113.csv
# Nan values for wavelets:adni_out02_harmonics/CommonHarWavelets_Harmonics113.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics114.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics115.csv
# Nan values for wavelets:adni_out02_harmonics/CommonHarWavelets_Harmonics115.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics116.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics117.csv
# Nan values for wavelets:adni_out02_harmonics/CommonHarWavelets_Harmonics117.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics118.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics119.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics120.csv
# Nan values for wavelets:adni_out02_harmonics/CommonHarWavelets_Harmonics120.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics121.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics122.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics123.csv
# Nan values for wavelets:adni_out02_harmonics/CommonHarWavelets_Harmonics123.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics124.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics125.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics126.csv
# Nan values for wavelets:adni_out02_harmonics/CommonHarWavelets_Harmonics126.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics127.csv
# Nan values for wavelets:adni_out02_harmonics/CommonHarWavelets_Harmonics127.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics128.csv
# Nan values for wavelets:adni_out02_harmonics/CommonHarWavelets_Harmonics128.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics129.csv
# Nan values for wavelets:adni_out02_harmonics/CommonHarWavelets_Harmonics129.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics130.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics131.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics132.csv
# Nan values for wavelets:adni_out02_harmonics/CommonHarWavelets_Harmonics132.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics133.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics134.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics135.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics136.csv
# Nan values for wavelets:adni_out02_harmonics/CommonHarWavelets_Harmonics136.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics137.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics138.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics139.csv
# Nan values for wavelets:adni_out02_harmonics/CommonHarWavelets_Harmonics139.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics140.csv
# Nan values for wavelets:adni_out02_harmonics/CommonHarWavelets_Harmonics140.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics141.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics142.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics143.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics144.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics145.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics146.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics147.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics148.csv
# Nan values for wavelets:adni_out02_harmonics/CommonHarWavelets_Harmonics148.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics149.csv
# Nan values for wavelets:adni_out02_harmonics/CommonHarWavelets_Harmonics149.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics150.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics151.csv
# Nan values for wavelets:adni_out02_harmonics/CommonHarWavelets_Harmonics151.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics152.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics153.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics154.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics155.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics156.csv
# Nan values for wavelets:adni_out02_harmonics/CommonHarWavelets_Harmonics156.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics157.csv
# Nan values for wavelets:adni_out02_harmonics/CommonHarWavelets_Harmonics157.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics158.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics159.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics160.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics161.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics162.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics163.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics164.csv
# Nan values for wavelets:adni_out02_harmonics/CommonHarWavelets_Harmonics164.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics165.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics166.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics167.csv
# Nan values for wavelets:adni_out02_harmonics/CommonHarWavelets_Harmonics167.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics168.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics169.csv
# Nan values for wavelets:adni_out02_harmonics/CommonHarWavelets_Harmonics169.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics170.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics171.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics172.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics173.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics174.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics175.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics176.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics177.csv
# Nan values for wavelets:adni_out02_harmonics/CommonHarWavelets_Harmonics177.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics178.csv
# Nan values for wavelets:adni_out02_harmonics/CommonHarWavelets_Harmonics178.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics179.csv
# Nan values for wavelets:adni_out02_harmonics/CommonHarWavelets_Harmonics179.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics180.csv
# Nan values for wavelets:adni_out02_harmonics/CommonHarWavelets_Harmonics180.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics181.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics182.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics183.csv
# Nan values for wavelets:adni_out02_harmonics/CommonHarWavelets_Harmonics183.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics184.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics185.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics186.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics187.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics188.csv
# Nan values for wavelets:adni_out02_harmonics/CommonHarWavelets_Harmonics188.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics189.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics190.csv
# Nan values for wavelets:adni_out02_harmonics/CommonHarWavelets_Harmonics190.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics191.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics192.csv
# Nan values for wavelets:adni_out02_harmonics/CommonHarWavelets_Harmonics192.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics193.csv
# Nan values for wavelets:adni_out02_harmonics/CommonHarWavelets_Harmonics193.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics194.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics195.csv
# Nan values for wavelets:adni_out02_harmonics/CommonHarWavelets_Harmonics195.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics196.csv
# Nan values for wavelets:adni_out02_harmonics/CommonHarWavelets_Harmonics196.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics197.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics198.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics199.csv
# Nan values for wavelets:adni_out02_harmonics/CommonHarWavelets_Harmonics199.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics200.csv
# Nan values for wavelets:adni_out02_harmonics/CommonHarWavelets_Harmonics200.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics201.csv
# Nan values for wavelets:adni_out02_harmonics/CommonHarWavelets_Harmonics201.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics202.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics203.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics204.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics205.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics206.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics207.csv
# Nan values for wavelets:adni_out02_harmonics/CommonHarWavelets_Harmonics207.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics208.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics209.csv
# Nan values for wavelets:adni_out02_harmonics/CommonHarWavelets_Harmonics209.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics210.csv
# Nan values for wavelets:adni_out02_harmonics/CommonHarWavelets_Harmonics210.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics211.csv
# Nan values for wavelets:adni_out02_harmonics/CommonHarWavelets_Harmonics211.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics212.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics213.csv
# Nan values for wavelets:adni_out02_harmonics/CommonHarWavelets_Harmonics213.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics214.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics215.csv
# Nan values for wavelets:adni_out02_harmonics/CommonHarWavelets_Harmonics215.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics216.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics217.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics218.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics219.csv
# Nan values for wavelets:adni_out02_harmonics/CommonHarWavelets_Harmonics219.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics220.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics221.csv
# Nan values for wavelets:adni_out02_harmonics/CommonHarWavelets_Harmonics221.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics222.csv
# Nan values for wavelets:adni_out02_harmonics/CommonHarWavelets_Harmonics222.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics223.csv
# Nan values for wavelets:adni_out02_harmonics/CommonHarWavelets_Harmonics223.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics224.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics225.csv
# Nan values for wavelets:adni_out02_harmonics/CommonHarWavelets_Harmonics225.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics226.csv
# Nan values for wavelets:adni_out02_harmonics/CommonHarWavelets_Harmonics226.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics227.csv
# Nan values for wavelets:adni_out02_harmonics/CommonHarWavelets_Harmonics227.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics228.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics229.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics230.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics231.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics232.csv
# Nan values for wavelets:adni_out02_harmonics/CommonHarWavelets_Harmonics232.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics233.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics234.csv
# Nan values for wavelets:adni_out02_harmonics/CommonHarWavelets_Harmonics234.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics235.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics236.csv
# Nan values for wavelets:adni_out02_harmonics/CommonHarWavelets_Harmonics236.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics237.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics238.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics239.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics240.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics241.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics242.csv
# Nan values for wavelets:adni_out02_harmonics/CommonHarWavelets_Harmonics242.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics243.csv
# Nan values for wavelets:adni_out02_harmonics/CommonHarWavelets_Harmonics243.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics244.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics245.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics246.csv
# Nan values for wavelets:adni_out02_harmonics/CommonHarWavelets_Harmonics246.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics247.csv
# Nan values for wavelets:adni_out02_harmonics/CommonHarWavelets_Harmonics247.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics248.csv
# Nan values for wavelets:adni_out02_harmonics/CommonHarWavelets_Harmonics248.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics249.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics250.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics251.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics252.csv
# Nan values for wavelets:adni_out02_harmonics/CommonHarWavelets_Harmonics252.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics253.csv
# Nan values for wavelets:adni_out02_harmonics/CommonHarWavelets_Harmonics253.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics254.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics255.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics256.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics257.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics258.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics259.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics260.csv
# Nan values for wavelets:adni_out02_harmonics/CommonHarWavelets_Harmonics260.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics261.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics262.csv
# Nan values for wavelets:adni_out02_harmonics/CommonHarWavelets_Harmonics262.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics263.csv
# adni_out02_harmonics/CommonHarWavelets_Harmonics264.csv

# %%
time_signal.isna().any(axis = None)
# Out:
# False

# %%
# check for NaN values in wavelets:
print(wavelets.isna().any(axis=0))
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6    False
# 7    False
# 8    False
# 9    False
# dtype: bool

# %%
## save spectrum for each time point (row of P) and frequency (column of P):
num_time_points = P.shape[0]
num_frequency = P.shape[1]

for i in range(num_time_points):
    for j in range(num_frequency):
        result = []
        
        for brain_index in range(len(spectrum_list)):
            result_row = []
            for subj in range(len(spectrum_list[0])):
                P = spectrum_list[brain_index][subj]
                result_row.append(P[i, j])
            result.append(result_row)
    
        out_file_name = output_dir + '/spectrum_' + '{:03}'.format(j) + '_time_' + '{:03}'.format(i) + '.csv'
        np.savetxt(out_file_name, np.array(result).transpose(), delimiter = ',')

# %%
len(spectrum_list[0])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [1], in <cell line: 1>()
# ----> 1 len(spectrum_list[0])
#
# NameError: name 'spectrum_list' is not defined

# %%
## make histogram

## calculate entropy
